# %%
# !pip install git+https://github.com/Fede-stack/TONYpy.git

# %%
import pandas as pd
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

url_train = "https://raw.githubusercontent.com/drmuskangarg/Irf/refs/heads/main/train_data.csv"
train = pd.read_csv(url_train)
train.to_csv('train_irf.csv', index = False)

url_test = "https://raw.githubusercontent.com/drmuskangarg/Irf/refs/heads/main/test_data.csv"
test = pd.read_csv(url_test)
test.to_csv('test_irf.csv', index = False)

y_train_bel = train.belong
y_train_bur = train.burden
y_test_bel = test.belong
y_test_bur = test.burden

# %%
train.head()

# %%
from TONY.Lexicon import MarkersExtractionColab

# %%
app = MarkersExtractionColab()
# Out:
# VBox(children=(HTML(value='<h3>🧠 TONY — Linguistic Marker Extractor</h3>'), FileUpload(value={}, accept='.csv'…

# %%
markers_test
# Out:
#       lexical_diversity  word_prevalence  frequency_rare_mean_frequency  \
# 0              0.756098         0.195122                       0.005722
# 1              0.685315         0.286713                       0.007230
# 2              0.687117         0.190184                       0.007426
# 3              0.769231         0.219780                       0.005653
# 4              0.643836         0.219178                       0.006792
# ...                 ...              ...                            ...
# 1052           0.625000         0.238095                       0.005460
# 1053           0.960000         0.200000                       0.004910
# 1054           0.785714         0.267857                       0.006345
# 1055           0.883721         0.162791                       0.007306
# 1056           0.732558         0.302326                       0.005560
#
#       frequency_rare_std_frequency  sentence_complexity  subordination_rate  \
# 0                         0.010318             0.069860            0.012195
# 1                         0.012223             0.096079            0.034965
# 2                         0.012867             0.105728            0.024540
# 3                         0.010051             0.064015            0.000000
# 4                         0.011750             0.049918            0.000000
# ...                            ...                  ...                 ...
# 1052                      0.008920             0.097490            0.035714
# 1053                      0.008172             0.035714            0.000000
# 1054                      0.011409             0.111905            0.071429
# 1055                      0.011143             0.099781            0.000000
# 1056                      0.007922             0.164419            0.046512
#
#       coordination_rate  mean_dependency_distance  pronoun_first_person  \
# 0              0.060976                    2.1250              0.109756
# 1              0.062937                    1.9843              0.125874
# 2              0.073620                    2.3404              0.085890
# 3              0.054945                    1.9595              0.142857
# 4              0.068493                    2.3622              0.130137
# ...                 ...                       ...                   ...
# 1052           0.047619                    2.3893              0.107143
# 1053           0.040000                    1.4286              0.120000
# 1054           0.053571                    2.3542              0.125000
# 1055           0.093023                    2.2105              0.069767
# 1056           0.081395                    2.9250              0.127907
#
#       pronoun_second_person  ...  morph_indicative_ratio  \
# 0                  0.000000  ...                  0.4500
# 1                  0.006993  ...                  0.2500
# 2                  0.000000  ...                  0.0976
# 3                  0.000000  ...                  0.1000
# 4                  0.000000  ...                  0.1795
# ...                     ...  ...                     ...
# 1052               0.005952  ...                  0.1000
# 1053               0.000000  ...                  0.3333
# 1054               0.000000  ...                  0.1429
# 1055               0.000000  ...                  0.2000
# 1056               0.000000  ...                  0.2353
#
#       morph_subjunctive_ratio  morph_singular_ratio  morph_plural_ratio  \
# 0                         0.0                0.8333              0.1667
# 1                         0.0                0.8182              0.1818
# 2                         0.0                0.7407              0.2593
# 3                         0.0                0.8571              0.1429
# 4                         0.0                0.7895              0.2105
# ...                       ...                   ...                 ...
# 1052                      0.0                0.7857              0.2143
# 1053                      0.0                0.5000              0.5000
# 1054                      0.0                1.0000              0.0000
# 1055                      0.0                0.7143              0.2857
# 1056                      0.0                0.9333              0.0667
#
#       dep_nsubj_rate  dep_dobj_rate  ner_person_ref_rate  \
# 0             1.3333         1.1667                  0.0
# 1             1.2941         0.7647                  0.0
# 2             1.4167         0.8333                  0.0
# 3             1.0000         0.5000                  0.0
# 4             1.6364         0.9091                  0.0
# ...              ...            ...                  ...
# 1052          2.0000         0.5833                  0.0
# 1053          0.7500         0.7500                  0.0
# 1054          1.3333         1.0000                  0.0
# 1055          2.5000         0.5000                  0.0
# 1056          3.6667         2.0000                  0.0
#
#       ner_temporal_ref_rate  past_future_ratio  repetition_rate
# 0                    0.0256             0.3136           0.2439
# 1                    0.0139             0.1643           0.3147
# 2                    0.0000             0.1699           0.3129
# 3                    0.0000             0.3285           0.2308
# 4                    0.0365             0.2151           0.3562
# ...                     ...                ...              ...
# 1052                 0.0063             0.2306           0.3750
# 1053                 0.0000             0.0000           0.0400
# 1054                 0.0000             0.1054           0.2143
# 1055                 0.0750             0.2513           0.1163
# 1056                 0.0000             0.0741           0.2674
#
# [1057 rows x 68 columns]

# %%
base_lr = LogisticRegression(random_state=0, max_iter=5000)
pipe_lr = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', base_lr),
])

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
pipe_lr.fit(markers_train, y_train_bel)
preds_lr = pipe_lr.predict(markers_test)
print('Logistic Regression')
print('Thwarted Belongingness')
print(accuracy_score(y_test_bel, preds_lr))
print(f1_score(y_test_bel, preds_lr))
print(precision_score(y_test_bel, preds_lr))
print(recall_score(y_test_bel, preds_lr))

pipe_lr.fit(markers_train, y_train_bur)
preds_lr = pipe_lr.predict(markers_test)
print(' Perceived Burdensomeness')
print(accuracy_score(y_test_bur, preds_lr))
print(f1_score(y_test_bur, preds_lr))
print(precision_score(y_test_bur, preds_lr))
print(recall_score(y_test_bur, preds_lr))
# Out:
# Logistic Regression
# belongness
# 0.6963103122043519
# 0.7201394943330427
# 0.7348754448398577
# 0.705982905982906
# burden
# 0.7786187322611163
# 0.5880281690140845
# 0.6872427983539094
# 0.5138461538461538

# %% [markdown]
# # Empath

# %%
pip install empath
# Out:
# Collecting empath
#   Downloading empath-0.89.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from empath) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->empath) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->empath) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->empath) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->empath) (2026.1.4)
# Building wheels for collected packages: empath
#   Building wheel for empath (setup.py) ... done
#   Created wheel for empath: filename=empath-0.89-py3-none-any.whl size=57799 sha256=c02df1c4ade296367b662d7d0b7f60988fa70807d012fd57cd4b02b770c884f7
#   Stored in directory: /root/.cache/pip/wheels/b5/e9/20/019c1afcddedf93646169dcd5a99a28ca74ee6cf6ad23ccbdf
# Successfully built empath
# Installing collected packages: empath
# Successfully installed empath-0.89

# %%
from empath import Empath

lexicon = Empath()
empaths_features_train = [list(lexicon.analyze(text, normalize=True).values()) for text in train.text.values.tolist()]
empaths_features_test = [list(lexicon.analyze(text, normalize=True).values()) for text in test.text.values.tolist()]

# %%
base_lr = LogisticRegression(random_state=0, max_iter=5000)
pipe_lr = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', base_lr),
])

print('Logistic Regression with Empath features')
pipe_lr.fit(empaths_features_train, y_train_bel)
preds_lr = pipe_lr.predict(empaths_features_test)
print('Thwarted Belongingness')
print(accuracy_score(y_test_bel, preds_lr))
print(f1_score(y_test_bel, preds_lr))
print(precision_score(y_test_bel, preds_lr))
print(recall_score(y_test_bel, preds_lr))

pipe_lr.fit(empaths_features_train, y_train_bur)
preds_lr = pipe_lr.predict(empaths_features_test)
print(' Perceived Burdensomeness')
print(accuracy_score(y_test_bur, preds_lr))
print(f1_score(y_test_bur, preds_lr))
print(precision_score(y_test_bur, preds_lr))
print(recall_score(y_test_bur, preds_lr))
# Out:
# Logistic Regression with Empath features
# belongness
# 0.6206244087038789
# 0.6621735467565291
# 0.6528239202657807
# 0.6717948717948717
# burden
# 0.7095553453169348
# 0.45080500894454384
# 0.5384615384615384
# 0.38769230769230767
